# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
Knn = KNeighborsClassifier(n_neighbors=5)

# %%
df = pd.read_csv("UniversalBank.csv").iloc[:,1:]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.iloc[:,:-1]
y = df.loc[:,"CreditCard"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
Knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = Knn.predict(X_test)

# %%
y_lable = []
for i in range(1,101):
    Knn = KNeighborsClassifier(n_neighbors=i)
    Knn.fit(X_train,y_train)
    y_pred = Knn.predict(X_test)
    y_lable.append(accuracy_score(y_test, y_pred))

x_label = range(1,101)

# %%
data= pd.DataFrame({"kvalue" : "x_label", "accscore" : y_lable})
plt.plot(x_label, y_lable)

# %%
data[data["accscore"] == max(data["accscore"])]
# Out:
#      kvalue  accscore
# 40  x_label     0.774
# 41  x_label     0.774
# 42  x_label     0.774
# 43  x_label     0.774
# 44  x_label     0.774
# 45  x_label     0.774
# 46  x_label     0.774
# 47  x_label     0.774
# 48  x_label     0.774
# 49  x_label     0.774
# 50  x_label     0.774
# 51  x_label     0.774
# 52  x_label     0.774
# 53  x_label     0.774
# 54  x_label     0.774
# 55  x_label     0.774
# 61  x_label     0.774
# 62  x_label     0.774
# 63  x_label     0.774
# 64  x_label     0.774
# 65  x_label     0.774
# 66  x_label     0.774
# 67  x_label     0.774
# 68  x_label     0.774
# 69  x_label     0.774
# 71  x_label     0.774
# 75  x_label     0.774
# 76  x_label     0.774
# 77  x_label     0.774
# 78  x_label     0.774
# 79  x_label     0.774
# 81  x_label     0.774
# 82  x_label     0.774
# 83  x_label     0.774
# 84  x_label     0.774
# 85  x_label     0.774
# 86  x_label     0.774
# 87  x_label     0.774
# 88  x_label     0.774
# 89  x_label     0.774
# ...

# %%
most optimal k value is
